# %% [markdown]
# # Data Science Project

# %%
# imports and class instantiation
import main
import pandas as pd
import os
analysis:main.analyze = main.analyze(run_feature_importance_model=False)
# Out:
# Data shape: (4700, 31)
# Data dictionary shape: (31, 11)

# %% [markdown]
# ## Feature Selection

# %%
# Feature Selection Code
analysis.feature_selection()
# Out:
# Selected features (post-L1): 14
# [LightGBM] [Info] Number of positive: 2533, number of negative: 757
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000223 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1217
# [LightGBM] [Info] Number of data points in the train set: 3290, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# C:\Users\eappel\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# ...

# %% [markdown]
# ## Hyperparameter Search

# %%
# Grid Search Code
analysis.grid_search()
# Out:
# Data shape: (4700, 31)
# Data dictionary shape: (31, 11)
#        days_from_registration        income  alt_risk_score  alt_risk_score_2  \
# count             4656.000000  4.657000e+03     4538.000000       3562.000000
# mean              2488.531787  5.783508e+04      512.856324        529.246491
# std               1321.208541  8.065972e+05       36.593588         41.304003
# min                  1.000000  2.000000e+01      408.000000        391.000000
# 25%               1391.750000  3.120000e+04      493.000000        498.000000
# 50%               2692.000000  4.030000e+04      515.000000        527.000000
# 75%               3584.250000  5.200000e+04      536.000000        559.000000
# max               5916.000000  5.500000e+07      702.000000        687.000000
#
#        asset_score
# count  4628.000000
# mean   1624.710890
# std    3412.100395
# min       1.000000
# 25%      17.000000
# 50%      39.000000
# 75%     105.000000
# max    9003.000000
# ...
