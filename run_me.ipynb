# %% [markdown]
# # Data Science Project

# %%
# imports and class instantiation
import main
import pandas as pd
import os
analysis:main.analyze = main.analyze()

# %% [markdown]
# ## Feature Selection

# %%
# Feature Selection Code
analysis.feature_selection()

# %% [markdown]
# ## Hyperparameter Search

# %%
# Grid Search Code
analysis.grid_search()
